# %% [markdown]
# ### I. Import Library

# %%
import pandas as pd
import os


pd.set_option('display.max_columns', None)

# %% [markdown]
# ### II. Loading Dataset

# %%
df = pd.DataFrame()
for i in os.listdir('dataset'):
    sensor = i.split('.')[0]
    raw_df = pd.read_csv(f'dataset/{i}',delimiter=';')
    raw_df['sensor'] = raw_df.apply(lambda x : sensor, axis=1)
    df = pd.concat([df,raw_df])

# %%
df
# Out:
#     0.799_0.201_MIP  0.799_0.201_NP  0.700_0.300_MIP  0.700_0.300_NP  \
# 0            -11.98          -10.99           -19.12          -17.28
# 1            -12.15          -11.33           -22.33          -19.95
# 2            -12.58          -11.74           -26.67          -23.34
# 3            -13.79          -12.82           -30.56          -26.18
# 4            -15.73          -13.87           -34.54          -28.65
# ..              ...             ...              ...             ...
# 20           -27.45          -40.42           -42.10          -56.14
# 21           -28.79          -41.95           -43.33          -56.89
# 22           -29.59          -42.61           -43.82          -57.46
# 23           -29.98          -42.70           -44.41          -57.80
# 24           -30.95          -42.82           -45.26          -57.19
#
#     0.600_0.400_MIP  0.600_0.400_NP  0.501_0.499_MIP  0.501_0.499_NP  \
# ...

# %%
df['type'] = df[['1-Octanol','1-Propanol','2-Butanol','2-propanol','1-isobutanol']].idxmax(axis=1)
df.drop(columns=['1-Octanol','1-Propanol','2-Butanol','2-propanol','1-isobutanol'],inplace=True)

# %%
df.head(10)
# Out:
#    0.799_0.201_MIP  0.799_0.201_NP  0.700_0.300_MIP  0.700_0.300_NP  \
# 0           -11.98          -10.99           -19.12          -17.28
# 1           -12.15          -11.33           -22.33          -19.95
# 2           -12.58          -11.74           -26.67          -23.34
# 3           -13.79          -12.82           -30.56          -26.18
# 4           -15.73          -13.87           -34.54          -28.65
# 5           -58.41          -38.66           -83.58          -57.33
# 6           -59.68          -40.01           -84.75          -58.75
# 7           -60.12          -40.73           -85.19          -59.47
# 8           -60.41          -41.20           -84.73          -59.31
# 9           -60.87          -39.88           -84.22          -57.58
#
#    0.600_0.400_MIP  0.600_0.400_NP  0.501_0.499_MIP  0.501_0.499_NP  \
# 0           -33.13          -28.45           -48.83          -40.77
# 1           -39.82          -33.64           -56.90          -46.77
# ...

# %%
df.to_csv('dataset_final.csv',index=False)
