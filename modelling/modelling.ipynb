# %% [markdown]
# ### I. Introduction

# %% [markdown]
# ### II. Import Library

# %%
random = 12
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns


# split data into train and test
from sklearn.model_selection import train_test_split

# %% [markdown]
# ### III. Loading Dataset

# %%
df = pd.read_csv('dataset_final.csv')
df.head(25)
# Out:
#     0.799_0.201_MIP  0.799_0.201_NP  0.700_0.300_MIP  0.700_0.300_NP  \
# 0            -11.98          -10.99           -19.12          -17.28
# 1            -12.15          -11.33           -22.33          -19.95
# 2            -12.58          -11.74           -26.67          -23.34
# 3            -13.79          -12.82           -30.56          -26.18
# 4            -15.73          -13.87           -34.54          -28.65
# 5            -58.41          -38.66           -83.58          -57.33
# 6            -59.68          -40.01           -84.75          -58.75
# 7            -60.12          -40.73           -85.19          -59.47
# 8            -60.41          -41.20           -84.73          -59.31
# 9            -60.87          -39.88           -84.22          -57.58
# 10           -59.41          -61.86           -91.65          -81.02
# 11           -61.16          -62.92           -93.55          -82.39
# 12           -61.80          -62.99           -94.15          -82.45
# 13           -61.94          -62.78           -94.46          -82.39
# 14           -62.34          -61.87           -95.09          -81.53
# 15           -44.10          -35.02           -66.13          -50.43
# 16           -44.67          -35.39           -66.62          -50.84
# 17           -44.50          -35.27           -66.60          -50.98
# 18           -44.34          -34.97           -66.58          -50.93
# 19           -44.80          -35.17           -66.20          -50.42
# 20           -52.22          -41.67           -75.74          -57.70
# 21           -54.15          -42.91           -77.43          -59.33
# 22           -54.72          -43.04           -78.19          -60.05
# 23           -54.54          -42.61           -78.67          -60.59
# 24           -54.47          -41.87           -79.15          -60.58
#
#     0.600_0.400_MIP  0.600_0.400_NP  0.501_0.499_MIP  0.501_0.499_NP  \
# 0            -33.13          -28.45           -48.83          -40.77
# 1            -39.82          -33.64           -56.90          -46.77
# 2            -46.48          -38.69           -65.95          -53.46
# 3            -52.30          -42.98           -73.81          -59.19
# 4            -57.44          -46.26           -80.37          -63.49
# 5           -110.24          -76.80          -133.77          -96.13
# 6           -109.91          -77.28          -130.65          -94.69
# 7           -108.08          -76.43          -127.51          -92.88
# 8           -106.46          -75.39          -124.62          -90.88
# 9           -105.32          -73.36          -122.59          -88.28
# 10          -131.05         -105.51          -165.68         -126.30
# 11          -133.11         -107.27          -168.62         -128.94
# 12          -133.24         -107.15          -165.33         -126.55
# 13          -131.54         -105.60          -160.74         -123.08
# 14          -128.23         -102.05          -156.31         -119.71
# 15           -90.29          -68.00          -101.74          -76.53
# 16           -84.41          -63.94           -97.11          -73.35
# 17           -80.79          -61.24           -93.34          -70.67
# 18           -78.07          -59.27           -89.95          -68.18
# 19           -76.80          -58.26           -87.09          -65.55
# 20          -109.10          -83.42          -149.62         -114.96
# 21          -112.04          -86.16          -155.04         -119.56
# 22          -113.36          -87.50          -157.68         -121.95
# 23          -114.31          -88.44          -158.35         -122.77
# 24          -115.72          -89.26          -159.23         -122.95
#
#     0.400_0.600_MIP  0.400_0.600_NP sensor          type
# 0            -62.49          -50.82  QCM10     1-Octanol
# 1            -73.32          -58.96  QCM10     1-Octanol
# 2            -84.53          -67.21  QCM10     1-Octanol
# 3            -94.41          -74.40  QCM10     1-Octanol
# 4           -102.94          -80.25  QCM10     1-Octanol
# 5           -171.05         -124.15  QCM10    1-Propanol
# 6           -161.81         -118.70  QCM10    1-Propanol
# 7           -155.54         -114.76  QCM10    1-Propanol
# 8           -151.56         -112.58  QCM10    1-Propanol
# 9           -146.99         -109.52  QCM10    1-Propanol
# 10          -207.16         -153.44  QCM10     2-Butanol
# 11          -210.85         -157.01  QCM10     2-Butanol
# 12          -204.60         -152.81  QCM10     2-Butanol
# 13          -195.49         -146.26  QCM10     2-Butanol
# 14          -187.95         -140.79  QCM10     2-Butanol
# 15          -117.67          -88.63  QCM10    2-propanol
# 16          -111.06          -83.98  QCM10    2-propanol
# 17          -106.18          -80.45  QCM10    2-propanol
# 18          -101.46          -77.06  QCM10    2-propanol
# 19           -98.14          -73.89  QCM10    2-propanol
# 20          -197.35         -151.92  QCM10  1-isobutanol
# 21          -205.77         -159.30  QCM10  1-isobutanol
# 22          -207.96         -161.60  QCM10  1-isobutanol
# 23          -207.15         -161.37  QCM10  1-isobutanol
# 24          -200.98         -157.18  QCM10  1-isobutanol

# %%
df.shape
# Out:
# (125, 12)

# %% [markdown]
# ### IV. Exploratory Data Analysis

# %% [markdown]
# ### V. Data Preprocessing

# %% [markdown]
# #### Split Dataset

# %%
#countplot for y
plt.figure(figsize=(15,7.5))
sns.countplot(x=df.type)
plt.title('Satisfaction')
plt.show()

# percentage of y
print(df.type.value_counts(normalize=True))
# Out:
# type
# 1-Octanol       0.2
# 1-Propanol      0.2
# 2-Butanol       0.2
# 2-propanol      0.2
# 1-isobutanol    0.2
# Name: proportion, dtype: float64

# %%
# split data to X and y
X = df.drop(['type'], axis=1)
y = df['type']

# %%
# split X_train, X_test, y_train, y_test
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=random)

# X_train shape
print('X_train shape: ', X_train.shape)

# X_test shape
print('X_test shape: ', X_test.shape)
# Out:
# X_train shape:  (100, 11)
# X_test shape:  (25, 11)
